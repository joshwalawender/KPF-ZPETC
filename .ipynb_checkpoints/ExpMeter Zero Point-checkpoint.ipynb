# %%
from pathlib import Path
import numpy as np
from astropy import stats
from astropy.time import Time
from astropy.table import Table, MaskedColumn
from kpf_etc.etc import kpf_photon_noise_estimate

import matplotlib.pyplot as plt

data_file = 'data/Feb2026_anonymized.csv'
t = Table.read(data_file, format='ascii.csv')
len(t)
# Out:
# 12058

# %%
# KPFERA 1.0 is before SM1
SM1start = Time('2024-02-03')
SM1end = Time('2024-02-23')
# KPFERA 2.0 is between SM1 and SM2
SM2start = Time('2024-10-31')
SM2end = Time('2024-11-20')
# KPFERA 2.5/2.6 is between SM2 and SM3
SM3start = Time('2025-03-28')
SM3end = Time('2025-04-23')
# KPFERA 3.0 is between SM3 and SM4
SM4start = Time('2025-08-29')
SM4end = Time('2025-10-27')
# KPFERA 4.0 is after SM4

# %%
def Nmasked(data):
    return int(np.sum(np.array(t['TOTCORR'].mask, dtype=int)))

# %%
Nmasked(t)
# Out:
# 2004

# %%
# Mask out negative exposure meter flux
t['TOTCORR'].mask = t['TOTCORR'].mask | (t['TOTCORR_SUM'] <= 0).data
Nmasked(t)
# Out:
# 3651

# %%
# Mask out exposure meter data from before reformatter realignment
t['TOTCORR'].mask = t['TOTCORR'].mask | (t['MJD-OBS'] < SM1end.mjd).data
Nmasked(t)
# Out:
# 4709

# %%
t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_1'] / t['EXPTIME']), name='EMZP_1'))
t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_2'] / t['EXPTIME']), name='EMZP_2'))
t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_3'] / t['EXPTIME']), name='EMZP_3'))
t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_4'] / t['EXPTIME']), name='EMZP_4'))
t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_SUM'] / t['EXPTIME']), name='EMZP_SUM'))
print(len(t), Nmasked(t))
# Out:
# 12058 4709
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:1: RuntimeWarning: divide by zero encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_1'] / t['EXPTIME']), name='EMZP_1'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:1: RuntimeWarning: invalid value encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_1'] / t['EXPTIME']), name='EMZP_1'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:2: RuntimeWarning: divide by zero encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_2'] / t['EXPTIME']), name='EMZP_2'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:2: RuntimeWarning: invalid value encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_2'] / t['EXPTIME']), name='EMZP_2'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:3: RuntimeWarning: divide by zero encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_3'] / t['EXPTIME']), name='EMZP_3'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:3: RuntimeWarning: invalid value encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_3'] / t['EXPTIME']), name='EMZP_3'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:4: RuntimeWarning: divide by zero encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_4'] / t['EXPTIME']), name='EMZP_4'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:4: RuntimeWarning: invalid value encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_4'] / t['EXPTIME']), name='EMZP_4'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:5: RuntimeWarning: divide by zero encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_SUM'] / t['EXPTIME']), name='EMZP_SUM'))
# /var/folders/3m/rvt2qsdx3nv0cv6m5rvbbgzc0000gp/T/ipykernel_5234/1864448266.py:5: RuntimeWarning: invalid value encountered in log10
#   t.add_column(MaskedColumn(t['GAIAMAG'] + 2.5*np.log10(t[f'TOTCORR_SUM'] / t['EXPTIME']), name='EMZP_SUM'))

# %%
def calculate_ExpMeter_zero_point(t, EMbin=1, percentile=95, plot=False):
    mask = t['TOTCORR'].mask
    EMZP = float(np.percentile(t[f'EMZP_{EMbin}'][~mask], percentile))
    # print(f"Exposure Meter Zero Point = {EMZP:.2f}")

    if plot:
        plt.figure(figsize=(10,3))
        plt.title(f'Exposure Meter Zero Point (bin {EMbin}) = {EMZP:.2f}')
        plt.hist(t[f'EMZP_{EMbin}'][~mask], bins=100, density=True, label='Zero Points')
        plt.ylabel(f'Density (N={len(t[~mask])})')
        plt.axvline(EMZP, color='k', alpha=0.5, label='Nominal Zero Point')
        plt.grid()
        plt.legend(loc='best')
        plt.xlim(12,24)
        plt.xlabel('Zero Point (mag)')
        plt.show()

    return EMZP

# %%
EMZeroPoint = {}
for EMbin in [1, 2, 3, 4, 'SUM']:
    EMZeroPoint[EMbin] = calculate_ExpMeter_zero_point(t, EMbin=EMbin, percentile=95, plot=True)

# %%
EMZeroPoint
# Out:
# {1: 21.372837780991826,
#  2: 21.86128528452142,
#  3: 21.813791696161033,
#  4: 21.53655457132694,
#  'SUM': 23.12766392123874}

# %% [markdown]
# ## Check for Evolution Over Time

# %%
mask = t['TOTCORR'].mask
mjd = np.array([int(d) for d in t['MJD-OBS']])

plt.figure(figsize=(9,5))
labeled = False
for j,day in enumerate(set(mjd)):
    wday = (mjd == day) & ~mask
    if np.sum(np.array(wday, dtype=int)) > 5:
        if not labeled:
            plt.plot(day, np.median(t['EMZP_1'][wday]), 'bo', alpha=0.3, label='EMbin=1')
            plt.plot(day, np.median(t['EMZP_2'][wday]), 'co', alpha=0.3, label='EMbin=2')
            plt.plot(day, np.median(t['EMZP_3'][wday]), 'go', alpha=0.3, label='EMbin=3')
            plt.plot(day, np.median(t['EMZP_4'][wday]), 'ro', alpha=0.3, label='EMbin=4')
            plt.plot(day, np.median(t['EMZP_SUM'][wday]), 'ko', alpha=0.3, label='EMbin=SUM')
            labeled = True
        else:
            plt.plot(day, np.median(t['EMZP_1'][wday]), 'bo', alpha=0.3)
            plt.plot(day, np.median(t['EMZP_2'][wday]), 'co', alpha=0.3)
            plt.plot(day, np.median(t['EMZP_3'][wday]), 'go', alpha=0.3)
            plt.plot(day, np.median(t['EMZP_4'][wday]), 'ro', alpha=0.3)
            plt.plot(day, np.median(t['EMZP_SUM'][wday]), 'ko', alpha=0.3)

plt.axvspan(SM1start.mjd, SM1end.mjd, color='k', alpha=0.3, label='Servicing Mission')
plt.axvspan(SM2start.mjd, SM2end.mjd, color='k', alpha=0.3)
plt.axvspan(SM3start.mjd, SM3end.mjd, color='k', alpha=0.3)
plt.axvspan(SM4start.mjd, SM4end.mjd, color='k', alpha=0.3)
plt.xlabel('MJD')
plt.ylabel(f'Exposure Meter Zero Point')
plt.grid()
plt.legend(loc='best')
plt.show()
