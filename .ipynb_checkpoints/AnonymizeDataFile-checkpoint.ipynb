# %%
# Anonymize

# %%
from astropy.table import Table

# %%
t = Table.read('data/Feb2026.csv', format='ascii.csv')

# %%
t.remove_columns(['ObsID', 'OBJECT', 'TARGNAME', 'CCFRV_MPS', 'CCD1RV_MPS', 'CCD2RV_MPS', 'CCFERV_MPS', 'CCFBJD', 'CCFERV'])

# %%
t.write('data/Feb2026_anonymized.csv')
