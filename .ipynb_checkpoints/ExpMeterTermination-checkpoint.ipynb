# %%
from pathlib import Path
import yaml
import numpy as np
from astropy import stats
from astropy.time import Time
from astropy.table import Table, MaskedColumn
from kpf_etc.etc import kpf_photon_noise_estimate

import matplotlib.pyplot as plt

data_file = 'data/Feb2026_withInstZPs.csv'
t = Table.read(data_file, format='ascii.csv')

# %%
EMZPfile = Path('data/ExposureMeterZeroPoints.yaml')
with open(EMZPfile, 'r') as f:
    EMZeroPoint = yaml.safe_load(f)
EMZeroPoint
# Out:
# {1: 21.296749750531042,
#  2: 21.802875631774594,
#  3: 21.738583308861333,
#  4: 21.385165124935046,
#  'SUM': 23.06521519492087}

# %%
ZPfile = Path('data/InstrumentZeroPoints.yaml')
with open(ZPfile, 'r') as f:
    ZeroPoint = yaml.safe_load(f)
ZeroPoint
# Out:
# {'452': 13.664278495210038,
#  '548': 14.964690898633878,
#  '652': 15.329155098901115,
#  '747': 15.466755734095996,
#  '852': 15.073233551565435}

# %%
EMbinfile = Path('data/ExpMeterBins.yaml')
with open(EMbinfile, 'r') as f:
    best_EMbin = yaml.safe_load(f)
best_EMbin
# Out:
# {'452': 1, '548': 2, '652': 3, '747': 4, '852': 4}

# %%
A_per_pix = 0.0166

# %% [markdown]
# # Examine ExpMeter Termination Behavior

# %%
# From KPFTranslator (modified)
def expeter_flux_target(Mphotons_per_A, band):
    # photons/A near bin center divided by TOTCORR
    # bin1 / 498.125nm = 0.104 (1.4%)
    # bin2 / 604.375nm = 0.116 (0.8%)
    # bin3 / 710.625nm = 0.087 (2.2%)
    # bin4 / 816.875nm = 0.116 (0.8%)
    peak_photon_ratios = {'498.125': 0.104,
                          '604.375': 0.116,
                          '710.625': 0.087,
                          '816.875': 0.116}
    expmeter_threshold = 1e6*Mphotons_per_A/peak_photon_ratios[band]
    # Estimate SNR using empirical relation from example observations.
    # SNR is taken from DRP output at a few wavelengths.
    return expmeter_threshold

def instflux_from_expmeter(TOTCORR, EMbin):
    peak_photon_ratios = {'498.125': 0.104,
                          '604.375': 0.116,
                          '710.625': 0.087,
                          '816.875': 0.116}
    photons_per_A = TOTCORR*peak_photon_ratios[EMbin]
    photons_per_pix = A_per_pix*photons_per_A
    return photons_per_pix

# %%
emt = (t['USTHRSH'] == 'Yes') & ((t['EXPTIME'] - t['ELAPSED']) > 1)
t[emt]['DATE-MID', 'EXPTIME', 'ELAPSED', 'THRSBIN', 'TOTCORR_1']
# Out:
# <Table length=71>
#          DATE-MID          EXPTIME ELAPSED THRSBIN  TOTCORR_1
#           str26            float64 float64 float64   float64
# -------------------------- ------- ------- ------- -----------
# 2026-01-01 16:02:20.900000   250.0   9.221 498.125   9942700.0
# 2026-01-01 15:24:31.768000   600.0 128.231 498.125  96361000.0
# 2024-11-25 12:52:03.015000   600.0  274.84 604.375 251570000.0
# 2026-02-12 07:07:09.221000   600.0 537.197 498.125   4362700.0
# 2024-11-25 11:13:33.148000   600.0 251.352 604.375 258130000.0
# 2026-02-12 13:02:56.188000   600.0 420.888 498.125  48078000.0
# 2026-01-01 16:04:16.957000   250.0   9.214 498.125  10450000.0
# 2026-01-01 16:15:10.619000   600.0 104.838 498.125   9791700.0
# 2024-06-12 05:57:15.752000   409.0 192.748 498.125 377100000.0
#                        ...     ...     ...     ...         ...
# 2025-06-02 14:06:41.935000   120.0  83.636 498.125 642090000.0
# 2025-01-02 16:22:19.791000   409.0 288.507 498.125 375430000.0
# ...

# %%
EMbins = {498.125: 1, 604.375: 2, 710.625: 3, 816.875: 4}
SNRSCwav = {1: '452', 2: '548', 3: '747', 4: '852'}
conversions = {1: [], 2: [], 3: [], 4: []}
for row in t[emt]:
    EMbin = EMbins[row['THRSBIN']]
    EM_ADU = row[f'TOTCORR_{EMbin}']
    predicted_instflux = instflux_from_expmeter(EM_ADU, str(row['THRSBIN']))
    instflux = row[f'SNRSC{SNRSCwav[EMbin]}']
    conversions[EMbin].append(float(instflux/EM_ADU))
# Out:
# 1 5.05777037716123e-06 4.074605896572385e-06 3.2069207994677247e-06
# 2 2.893402214277466e-06 2.898219537397663e-06 1.4944353672709432e-08
# 3 1.4020503136813001e-05 1.4020503136813001e-05 2.634650250960116e-06
# 4 nan nan nan

# %%
plt.figure(figsize=(10,7))

for EMbin in [1, 2, 3, 4]:
    Nc = len(conversions[EMbin])
    plt.subplot(2,2,EMbin)
    plt.title(f'EMbin = {EMbin} (N={Nc})')
    if Nc > 0:
        mean, median, stdev = stats.sigma_clipped_stats(conversions[EMbin])
        plt.hist(conversions[EMbin], bins=20)
        plt.axvline(median, color='g')
plt.show()

# %%
# Look at all exposures

# %%
conversions = {}
for EMbin in [1, 2, 3, 4]:
    SNRSCwav = {1: '452', 2: '548', 3: '747', 4: '852'}
    mask = t[f'SNRSC{SNRSCwav[EMbin]}'].mask | t[f'TOTCORR_{EMbin}'].mask | (t[f'TOTCORR_{EMbin}'] <= 0) | (t[f'SNRSC{SNRSCwav[EMbin]}'] <= 0)
    conversions[EMbin] = t[~mask][f'TOTCORR_{EMbin}']/1e6/t[~mask][f'SNRSC{SNRSCwav[EMbin]}']
    czero = conversions[EMbin] == 0

# %%
plt.figure(figsize=(10,7))

for EMbin in [1, 2, 3, 4]:
    mean, median, stdev = stats.sigma_clipped_stats(conversions[EMbin])
    plt.subplot(2,2,EMbin)
    plt.title(f'EMbin={EMbin}: {median:.2f}+/-{stdev:.2f} MADU/photon')
    bins = np.linspace(median-5*stdev, median+5*stdev, 100)
    plt.hist(conversions[EMbin], bins=bins)
    plt.axvline(median, color='g')
    # plt.grid()
plt.show()

# %%
conversions[1][conversions[1] < 0.01]
# Out:
# <MaskedColumn name='TOTCORR_1' dtype='float64' length=19>
#  0.006010041619871837
#  0.006917303084755915
#  0.008785543105123389
#  0.004405217391304348
#  0.002310494117647059
#  0.006744938995296845
# 0.0011970571801080277
#  0.002758904508704203
#  0.009276367102868532
#   0.00906271878646441
# 0.0019020042194092825
#  0.006526964188658735
# 0.0003686602222422982
#  0.004003254437869823
#  0.003969413677471802
#  0.007040708711242354
#  0.006216314111851637
# 0.0034716596240711058
# 0.0022144651364226936
